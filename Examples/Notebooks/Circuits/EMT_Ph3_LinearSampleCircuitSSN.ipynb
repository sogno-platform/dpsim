# %% [markdown]
# # EMT Ph3 Linear Circuit SSN

# %% [markdown]
# ## Run C++ examples

# %%
import os
import subprocess

# %matplotlib widget

name = 'EMT_Ph3_LinearSampleCircuit'

dpsim_path = subprocess.Popen(['git', 'rev-parse', '--show-toplevel'], stdout=subprocess.PIPE).communicate()[0].rstrip().decode('utf-8')

path_exec = dpsim_path + '/build/Examples/Cxx/'
sim = subprocess.Popen([path_exec + name], stdout=subprocess.PIPE, stderr=subprocess.STDOUT)
print(sim.communicate()[0].decode())
# Out:
# [20:13:03.503452 EMT_Ph3_LinearSampleCircuit info] Initialize simulation: EMT_Ph3_LinearSampleCircuit
# [20:13:03.503587 MnaSolverFactory info] creating EigenDense solver implementation
# [20:13:03.504753 EMT_Ph3_LinearSampleCircuit info] Scheduling tasks.
# [20:13:03.505028 EMT_Ph3_LinearSampleCircuit info] Scheduling done.
# [20:13:03.505038 EMT_Ph3_LinearSampleCircuit info] Opening interfaces.
# [20:13:03.505041 EMT_Ph3_LinearSampleCircuit info] Start synchronization with remotes on 0 interfaces
# [20:13:03.505043 EMT_Ph3_LinearSampleCircuit info] Synchronized simulation start with remotes
# [20:13:03.505045 EMT_Ph3_LinearSampleCircuit info] Start simulation: EMT_Ph3_LinearSampleCircuit
# [20:13:03.505051 EMT_Ph3_LinearSampleCircuit info] Time step: 1.000000e-04
# [20:13:03.505056 EMT_Ph3_LinearSampleCircuit info] Final time: 1.000000e-01
# [20:13:03.599583 EMT_Ph3_LinearSampleCircuit info] Simulation calculation time: 0.094516
# [20:13:03.600602 EMT_Ph3_LinearSampleCircuit info] Simulation finished.

# %%
from villas.dataprocessing.readtools import *
from villas.dataprocessing.timeseries import *
from villas.dataprocessing.timeseries import TimeSeries as ts
import matplotlib.pyplot as plt
import re
import numpy as np
import math

import os

result_name = 'EMT_Ph3_LinearSampleCircuit'

work_dir = os.getcwd() + "/logs/"

path_logfile = work_dir + result_name + "/" + result_name + ".csv"
ts_dpsim_EMT = read_timeseries_dpsim(path_logfile)
# Out:
# column number: 3
# results length: 1000
# real column names: ['I_R_0', 'I_R_1', 'I_R_2']
# complex column names: []

# %%
import os
import subprocess

# %matplotlib widget

name = 'EMT_Ph3_LinearSampleCircuitSSN'

dpsim_path = subprocess.Popen(['git', 'rev-parse', '--show-toplevel'], stdout=subprocess.PIPE).communicate()[0].rstrip().decode('utf-8')

path_exec = dpsim_path + '/build/Examples/Cxx/'
sim = subprocess.Popen([path_exec + name], stdout=subprocess.PIPE, stderr=subprocess.STDOUT)
print(sim.communicate()[0].decode())
# Out:
# [20:18:09.810759 EMT_Ph3_LinearSampleCircuitSSN info] Initialize simulation: EMT_Ph3_LinearSampleCircuitSSN
# [20:18:09.810899 MnaSolverFactory info] creating EigenDense solver implementation
# [20:18:09.811882 EMT_Ph3_LinearSampleCircuitSSN info] Scheduling tasks.
# [20:18:09.812105 EMT_Ph3_LinearSampleCircuitSSN info] Scheduling done.
# [20:18:09.812111 EMT_Ph3_LinearSampleCircuitSSN info] Opening interfaces.
# [20:18:09.812113 EMT_Ph3_LinearSampleCircuitSSN info] Start synchronization with remotes on 0 interfaces
# [20:18:09.812114 EMT_Ph3_LinearSampleCircuitSSN info] Synchronized simulation start with remotes
# [20:18:09.812116 EMT_Ph3_LinearSampleCircuitSSN info] Start simulation: EMT_Ph3_LinearSampleCircuitSSN
# [20:18:09.812128 EMT_Ph3_LinearSampleCircuitSSN info] Time step: 1.000000e-04
# [20:18:09.812130 EMT_Ph3_LinearSampleCircuitSSN info] Final time: 1.000000e-01
# [20:18:09.862708 EMT_Ph3_LinearSampleCircuitSSN info] Simulation calculation time: 0.050570
# [20:18:09.863755 EMT_Ph3_LinearSampleCircuitSSN info] Simulation finished.

# %%
from villas.dataprocessing.readtools import *
from villas.dataprocessing.timeseries import *
from villas.dataprocessing.timeseries import TimeSeries as ts
import matplotlib.pyplot as plt
import re
import numpy as np
import math

import os

result_name = 'EMT_Ph3_LinearSampleCircuitSSN'

work_dir = os.getcwd() + "/logs/"

path_logfile = work_dir + result_name + "/" + result_name + ".csv"
ts_dpsim_SSN_EMT = read_timeseries_dpsim(path_logfile)
# Out:
# column number: 3
# results length: 1000
# real column names: ['I_RLC_SSN_0', 'I_RLC_SSN_1', 'I_RLC_SSN_2']
# complex column names: []

# %% [markdown]
# ### Load Results

# %%
plt.close('all')
fig1 = plt.figure()

plt.plot(ts_dpsim_EMT['i_L1_0'].time, ts_dpsim_EMT['i_L1_0'].values, "r-", label='V_C1_a')
plt.plot(ts_dpsim_EMT['i_L1_1'].time, ts_dpsim_EMT['i_L1_1'].values, "g-", label='V_C1_b')
plt.plot(ts_dpsim_EMT['i_L1_2'].time, ts_dpsim_EMT['i_L1_2'].values, "b-", label='V_C1_c')

plt.plot(ts_dpsim_SSN_EMT['i_L1_SSN_0'].time, ts_dpsim_SSN_EMT['i_L1_SSN_0'].values, "rx", markevery=10, label='V_C1_SSN_a')
plt.plot(ts_dpsim_SSN_EMT['i_L1_SSN_1'].time, ts_dpsim_SSN_EMT['i_L1_SSN_1'].values, "gx", markevery=10, label='V_C1_SSN_b')
plt.plot(ts_dpsim_SSN_EMT['i_L1_SSN_2'].time, ts_dpsim_SSN_EMT['i_L1_SSN_2'].values, "bx", markevery=10, label='V_C1_SSN_c')

plt.legend(loc = 4)
#plt.legend(bbox_to_anchor=(1,1))

plt.title('Comparison of resistive companion and SSN simulation: Inductor current')
plt.xlabel('t [s]')
plt.ylabel('Phase current [A]')
# Out:
# Text(0, 0.5, 'Phase current [A]')
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
plt.close('all')
fig1 = plt.figure()

plt.plot(ts_dpsim_EMT['v_c1_0'].time, ts_dpsim_EMT['v_c1_0'].values, "r-", label='V_C1_a')
plt.plot(ts_dpsim_EMT['v_c1_1'].time, ts_dpsim_EMT['v_c1_1'].values, "g-", label='V_C1_b')
plt.plot(ts_dpsim_EMT['v_c1_2'].time, ts_dpsim_EMT['v_c1_2'].values, "b-", label='V_C1_c')

plt.plot(ts_dpsim_SSN_EMT['v_c1_SSN_0'].time, ts_dpsim_SSN_EMT['v_c1_SSN_0'].values, "rx", markevery=10, label='V_C1_SSN_a')
plt.plot(ts_dpsim_SSN_EMT['v_c1_SSN_1'].time, ts_dpsim_SSN_EMT['v_c1_SSN_1'].values, "gx", markevery=10, label='V_C1_SSN_b')
plt.plot(ts_dpsim_SSN_EMT['v_c1_SSN_2'].time, ts_dpsim_SSN_EMT['v_c1_SSN_2'].values, "bx", markevery=10, label='V_C1_SSN_c')

plt.legend(loc = 4)
#plt.legend(bbox_to_anchor=(1,1))

plt.title('Comparison of resistive companion and SSN simulation: Capacitor voltage')
plt.xlabel('t [s]')
plt.ylabel('Phase voltage [V]')
# Out:
# Text(0, 0.5, 'Phase voltage [V]')
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
plt.close('all')
fig1 = plt.figure()

plt.plot(ts_dpsim_EMT['I_R_0'].time, ts_dpsim_EMT['I_R_0'].values, "r-", label='I_R_a')
plt.plot(ts_dpsim_EMT['I_R_1'].time, ts_dpsim_EMT['I_R_1'].values, "g-", label='I_R_b')
plt.plot(ts_dpsim_EMT['I_R_2'].time, ts_dpsim_EMT['I_R_2'].values, "b-", label='I_R_c')

plt.plot(ts_dpsim_SSN_EMT['I_RLC_SSN_0'].time, ts_dpsim_SSN_EMT['I_RLC_SSN_0'].values, "rx", markevery=10, label='I_RLC_SSN_a')
plt.plot(ts_dpsim_SSN_EMT['I_RLC_SSN_1'].time, ts_dpsim_SSN_EMT['I_RLC_SSN_1'].values, "gx", markevery=10, label='I_RLC_SSN_b')
plt.plot(ts_dpsim_SSN_EMT['I_RLC_SSN_2'].time, ts_dpsim_SSN_EMT['I_RLC_SSN_2'].values, "bx", markevery=10, label='I_RLC_SSN_c')

plt.legend(loc = 4)
#plt.legend(bbox_to_anchor=(1,1))

plt.title('Comparison of resistive companion and SSN simulation results')
plt.xlabel('t [s]')
plt.ylabel('Phase currents [A]')
# Out:
# Text(0, 0.5, 'Phase currents [A]')
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
