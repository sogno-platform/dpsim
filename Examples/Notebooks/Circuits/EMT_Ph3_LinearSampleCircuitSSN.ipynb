# %% [markdown]
# # EMT Ph3 Linear Circuit SSN

# %% [markdown]
# ## Run C++ examples

# %%
import os
import subprocess

# %matplotlib widget

name = 'EMT_Ph3_LinearSampleCircuitSSN'

dpsim_path = subprocess.Popen(['git', 'rev-parse', '--show-toplevel'], stdout=subprocess.PIPE).communicate()[0].rstrip().decode('utf-8')

path_exec = dpsim_path + '/build/Examples/Cxx/'
sim = subprocess.Popen([path_exec + name], stdout=subprocess.PIPE, stderr=subprocess.STDOUT)
print(sim.communicate()[0].decode())
# Out:
# [02:13:27.304190 EMT_Ph3_LinearSampleCircuitSSN info] Initialize simulation: EMT_Ph3_LinearSampleCircuitSSN
# [02:13:27.304287 MnaSolverFactory info] creating EigenDense solver implementation
# [02:13:27.304812 EMT_Ph3_LinearSampleCircuitSSN info] Scheduling tasks.
# [02:13:27.304995 EMT_Ph3_LinearSampleCircuitSSN info] Scheduling done.
# [02:13:27.305002 EMT_Ph3_LinearSampleCircuitSSN info] Opening interfaces.
# [02:13:27.305004 EMT_Ph3_LinearSampleCircuitSSN info] Start synchronization with remotes on 0 interfaces
# [02:13:27.305005 EMT_Ph3_LinearSampleCircuitSSN info] Synchronized simulation start with remotes
# [02:13:27.305007 EMT_Ph3_LinearSampleCircuitSSN info] Start simulation: EMT_Ph3_LinearSampleCircuitSSN
# [02:13:27.305010 EMT_Ph3_LinearSampleCircuitSSN info] Time step: 1.000000e-04
# [02:13:27.305013 EMT_Ph3_LinearSampleCircuitSSN info] Final time: 1.000000e-01
# [02:13:27.349011 EMT_Ph3_LinearSampleCircuitSSN info] Simulation calculation time: 0.043994
# [02:13:27.349344 EMT_Ph3_LinearSampleCircuitSSN info] Simulation finished.

# %% [markdown]
# ### Load Results

# %%
from villas.dataprocessing.readtools import *
from villas.dataprocessing.timeseries import *
from villas.dataprocessing.timeseries import TimeSeries as ts
import matplotlib.pyplot as plt
import re
import numpy as np
import math

import os

result_name = 'EMT_Ph3_LinearSampleCircuitSSN'

work_dir = os.getcwd() + "/logs/"

path_logfile = work_dir + result_name + "/" + result_name + ".csv"
ts_dpsim_EMT = read_timeseries_dpsim(path_logfile)
# Out:
# column number: 3
# results length: 1000
# real column names: ['I_RLC_0', 'I_RLC_1', 'I_RLC_2']
# complex column names: []

# %%
plt.figure()
plt.plot(ts_dpsim_EMT['Etorque'].time, ts_dpsim_EMT['Etorque'].values)
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
