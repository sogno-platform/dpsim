# %% [markdown]
# # Examples

# %%
# This line configures matplotlib to show figures embedded in the notebook, 
# instead of opening a new window for each figure. 
# %matplotlib inline
import importlib
import PlotTools as pt
importlib.reload(pt)
pt.plotResults('..\VisualStudio\DPSolverWin10\DPSolverWin10\data.csv',1)
# Out:
# (999, 3)

# %%
# %matplotlib inline
import importlib
import PlotTools as pt
importlib.reload(pt)
pt.plotResults('..\VisualStudio\DPSolverWin10\DPSolverWin10\data_20161114.csv',3)
# Out:
# (99, 7)
