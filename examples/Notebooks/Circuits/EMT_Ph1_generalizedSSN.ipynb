# %% [markdown]
# # Comparing RC and generalized two terminal SSN linear circuit simulations in EMT Ph1 domain
# ### Comparing EMT domain simulations of Ph1 linear circuits built from Resistive Companion (RC) component models against the same linear circuits build from generalized two terminal SSN (State Space Nodal) component models.

# %% [markdown]
# ## Run C++ examples: R1C1Vs, R1L1Vs and RLCVs circuits

# %%
import os
import subprocess

# %matplotlib widget

name = "EMT_Ph1_General2TerminalSSN"

dpsim_path = (
    subprocess.Popen(["git", "rev-parse", "--show-toplevel"], stdout=subprocess.PIPE)
    .communicate()[0]
    .rstrip()
    .decode("utf-8")
)

path_exec = dpsim_path + "/build/dpsim/examples/cxx/"
sim = subprocess.Popen(
    [path_exec + name], stdout=subprocess.PIPE, stderr=subprocess.STDOUT
)
print(sim.communicate()[0].decode())
# Out:
# [16:02:37.295613 EMT_Ph1_General2TerminalSSN_C1R1Vs_RC info] Initialize simulation: EMT_Ph1_General2TerminalSSN_C1R1Vs_RC
# [16:02:37.295790 MnaSolverFactory info] creating KLUAdapter solver implementation
# [16:02:37.296293 EMT_Ph1_General2TerminalSSN_C1R1Vs_RC info] Scheduling tasks.
# [16:02:37.296590 EMT_Ph1_General2TerminalSSN_C1R1Vs_RC info] Scheduling done.
# [16:02:37.296672 EMT_Ph1_General2TerminalSSN_C1R1Vs_RC info] Opening interfaces.
# [16:02:37.296681 EMT_Ph1_General2TerminalSSN_C1R1Vs_RC info] Start synchronization with remotes on interfaces
# [16:02:37.296683 EMT_Ph1_General2TerminalSSN_C1R1Vs_RC info] Synchronized simulation start with remotes
# [16:02:37.296687 EMT_Ph1_General2TerminalSSN_C1R1Vs_RC info] Start simulation: EMT_Ph1_General2TerminalSSN_C1R1Vs_RC
# [16:02:37.296694 EMT_Ph1_General2TerminalSSN_C1R1Vs_RC info] Time step: 1.000000e-04
# [16:02:37.296696 EMT_Ph1_General2TerminalSSN_C1R1Vs_RC info] Final time: 1.000000e-01
# [16:02:37.308249 EMT_Ph1_General2TerminalSSN_C1R1Vs_RC info] Simulation calculation time: 0.011523
# [16:02:37.309354 EMT_Ph1_General2TerminalSSN_C1R1Vs_RC info] Simulation finished.
# [16:02:37.310082 EMT_Ph1_General2TerminalSSN_C1R1Vs_generalizedSSN info] Initialize simulation: EMT_Ph1_General2TerminalSSN_C1R1Vs_generalizedSSN
# [16:02:37.310216 MnaSolverFactory info] creating KLUAdapter solver implementation
# [16:02:37.311236 EMT_Ph1_General2TerminalSSN_C1R1Vs_generalizedSSN info] Scheduling tasks.
# [16:02:37.311538 EMT_Ph1_General2TerminalSSN_C1R1Vs_generalizedSSN info] Scheduling done.
# [16:02:37.311612 EMT_Ph1_General2TerminalSSN_C1R1Vs_generalizedSSN info] Opening interfaces.
# [16:02:37.311628 EMT_Ph1_General2TerminalSSN_C1R1Vs_generalizedSSN info] Start synchronization with remotes on interfaces
# [16:02:37.311630 EMT_Ph1_General2TerminalSSN_C1R1Vs_generalizedSSN info] Synchronized simulation start with remotes
# [16:02:37.311633 EMT_Ph1_General2TerminalSSN_C1R1Vs_generalizedSSN info] Start simulation: EMT_Ph1_General2TerminalSSN_C1R1Vs_generalizedSSN
# [16:02:37.311637 EMT_Ph1_General2TerminalSSN_C1R1Vs_generalizedSSN info] Time step: 1.000000e-04
# [16:02:37.311639 EMT_Ph1_General2TerminalSSN_C1R1Vs_generalizedSSN info] Final time: 1.000000e-01
# [16:02:37.330142 EMT_Ph1_General2TerminalSSN_C1R1Vs_generalizedSSN info] Simulation calculation time: 0.018479
# [16:02:37.331341 EMT_Ph1_General2TerminalSSN_C1R1Vs_generalizedSSN info] Simulation finished.
# [16:02:37.331822 EMT_Ph1_General2TerminalSSN_L1R1Vs_RC info] Initialize simulation: EMT_Ph1_General2TerminalSSN_L1R1Vs_RC
# [16:02:37.331898 MnaSolverFactory info] creating KLUAdapter solver implementation
# [16:02:37.332135 EMT_Ph1_General2TerminalSSN_L1R1Vs_RC info] Scheduling tasks.
# [16:02:37.332330 EMT_Ph1_General2TerminalSSN_L1R1Vs_RC info] Scheduling done.
# [16:02:37.332375 EMT_Ph1_General2TerminalSSN_L1R1Vs_RC info] Opening interfaces.
# [16:02:37.332382 EMT_Ph1_General2TerminalSSN_L1R1Vs_RC info] Start synchronization with remotes on interfaces
# [16:02:37.332384 EMT_Ph1_General2TerminalSSN_L1R1Vs_RC info] Synchronized simulation start with remotes
# [16:02:37.332386 EMT_Ph1_General2TerminalSSN_L1R1Vs_RC info] Start simulation: EMT_Ph1_General2TerminalSSN_L1R1Vs_RC
# [16:02:37.332389 EMT_Ph1_General2TerminalSSN_L1R1Vs_RC info] Time step: 1.000000e-04
# [16:02:37.332391 EMT_Ph1_General2TerminalSSN_L1R1Vs_RC info] Final time: 1.000000e-01
# [16:02:37.340775 EMT_Ph1_General2TerminalSSN_L1R1Vs_RC info] Simulation calculation time: 0.008370
# [16:02:37.341397 EMT_Ph1_General2TerminalSSN_L1R1Vs_RC info] Simulation finished.
# [16:02:37.341843 EMT_Ph1_General2TerminalSSN_L1R1Vs_generalizedSSN info] Initialize simulation: EMT_Ph1_General2TerminalSSN_L1R1Vs_generalizedSSN
# [16:02:37.341916 MnaSolverFactory info] creating KLUAdapter solver implementation
# [16:02:37.342210 EMT_Ph1_General2TerminalSSN_L1R1Vs_generalizedSSN info] Scheduling tasks.
# [16:02:37.342405 EMT_Ph1_General2TerminalSSN_L1R1Vs_generalizedSSN info] Scheduling done.
# [16:02:37.342448 EMT_Ph1_General2TerminalSSN_L1R1Vs_generalizedSSN info] Opening interfaces.
# [16:02:37.342455 EMT_Ph1_General2TerminalSSN_L1R1Vs_generalizedSSN info] Start synchronization with remotes on interfaces
# [16:02:37.342457 EMT_Ph1_General2TerminalSSN_L1R1Vs_generalizedSSN info] Synchronized simulation start with remotes
# [16:02:37.342459 EMT_Ph1_General2TerminalSSN_L1R1Vs_generalizedSSN info] Start simulation: EMT_Ph1_General2TerminalSSN_L1R1Vs_generalizedSSN
# [16:02:37.342461 EMT_Ph1_General2TerminalSSN_L1R1Vs_generalizedSSN info] Time step: 1.000000e-04
# [16:02:37.342463 EMT_Ph1_General2TerminalSSN_L1R1Vs_generalizedSSN info] Final time: 1.000000e-01
# [16:02:37.363295 EMT_Ph1_General2TerminalSSN_L1R1Vs_generalizedSSN info] Simulation calculation time: 0.020814
# [16:02:37.364256 EMT_Ph1_General2TerminalSSN_L1R1Vs_generalizedSSN info] Simulation finished.
# [16:02:37.365778 EMT_Ph1_General2TerminalSSN_RLCVs_RC info] Initialize simulation: EMT_Ph1_General2TerminalSSN_RLCVs_RC
# [16:02:37.366004 MnaSolverFactory info] creating KLUAdapter solver implementation
# [16:02:37.366645 EMT_Ph1_General2TerminalSSN_RLCVs_RC info] Scheduling tasks.
# [16:02:37.367236 EMT_Ph1_General2TerminalSSN_RLCVs_RC info] Scheduling done.
# [16:02:37.367342 EMT_Ph1_General2TerminalSSN_RLCVs_RC info] Opening interfaces.
# [16:02:37.367359 EMT_Ph1_General2TerminalSSN_RLCVs_RC info] Start synchronization with remotes on interfaces
# [16:02:37.367363 EMT_Ph1_General2TerminalSSN_RLCVs_RC info] Synchronized simulation start with remotes
# [16:02:37.367378 EMT_Ph1_General2TerminalSSN_RLCVs_RC info] Start simulation: EMT_Ph1_General2TerminalSSN_RLCVs_RC
# [16:02:37.367396 EMT_Ph1_General2TerminalSSN_RLCVs_RC info] Time step: 1.000000e-04
# [16:02:37.367401 EMT_Ph1_General2TerminalSSN_RLCVs_RC info] Final time: 1.000000e-01
# [16:02:37.384286 EMT_Ph1_General2TerminalSSN_RLCVs_RC info] Simulation calculation time: 0.016847
# [16:02:37.384779 EMT_Ph1_General2TerminalSSN_RLCVs_RC info] Simulation finished.
# [16:02:37.385282 EMT_Ph1_General2TerminalSSN_RLCVs_explicitSSN info] Initialize simulation: EMT_Ph1_General2TerminalSSN_RLCVs_explicitSSN
# [16:02:37.385360 MnaSolverFactory info] creating KLUAdapter solver implementation
# [16:02:37.385632 EMT_Ph1_General2TerminalSSN_RLCVs_explicitSSN info] Scheduling tasks.
# [16:02:37.385817 EMT_Ph1_General2TerminalSSN_RLCVs_explicitSSN info] Scheduling done.
# [16:02:37.385862 EMT_Ph1_General2TerminalSSN_RLCVs_explicitSSN info] Opening interfaces.
# [16:02:37.385869 EMT_Ph1_General2TerminalSSN_RLCVs_explicitSSN info] Start synchronization with remotes on interfaces
# [16:02:37.385871 EMT_Ph1_General2TerminalSSN_RLCVs_explicitSSN info] Synchronized simulation start with remotes
# [16:02:37.385873 EMT_Ph1_General2TerminalSSN_RLCVs_explicitSSN info] Start simulation: EMT_Ph1_General2TerminalSSN_RLCVs_explicitSSN
# [16:02:37.385876 EMT_Ph1_General2TerminalSSN_RLCVs_explicitSSN info] Time step: 1.000000e-04
# [16:02:37.385877 EMT_Ph1_General2TerminalSSN_RLCVs_explicitSSN info] Final time: 1.000000e-01
# [16:02:37.401319 EMT_Ph1_General2TerminalSSN_RLCVs_explicitSSN info] Simulation calculation time: 0.015422
# [16:02:37.401924 EMT_Ph1_General2TerminalSSN_RLCVs_explicitSSN info] Simulation finished.
# [16:02:37.402395 EMT_Ph1_General2TerminalSSN_RLCVs_generalizedSSN info] Initialize simulation: EMT_Ph1_General2TerminalSSN_RLCVs_generalizedSSN
# [16:02:37.402470 MnaSolverFactory info] creating KLUAdapter solver implementation
# [16:02:37.402752 EMT_Ph1_General2TerminalSSN_RLCVs_generalizedSSN info] Scheduling tasks.
# [16:02:37.403026 EMT_Ph1_General2TerminalSSN_RLCVs_generalizedSSN info] Scheduling done.
# [16:02:37.403077 EMT_Ph1_General2TerminalSSN_RLCVs_generalizedSSN info] Opening interfaces.
# [16:02:37.403084 EMT_Ph1_General2TerminalSSN_RLCVs_generalizedSSN info] Start synchronization with remotes on interfaces
# [16:02:37.403086 EMT_Ph1_General2TerminalSSN_RLCVs_generalizedSSN info] Synchronized simulation start with remotes
# [16:02:37.403088 EMT_Ph1_General2TerminalSSN_RLCVs_generalizedSSN info] Start simulation: EMT_Ph1_General2TerminalSSN_RLCVs_generalizedSSN
# [16:02:37.403091 EMT_Ph1_General2TerminalSSN_RLCVs_generalizedSSN info] Time step: 1.000000e-04
# [16:02:37.403093 EMT_Ph1_General2TerminalSSN_RLCVs_generalizedSSN info] Final time: 1.000000e-01
# [16:02:37.419904 EMT_Ph1_General2TerminalSSN_RLCVs_generalizedSSN info] Simulation calculation time: 0.016790
# [16:02:37.420272 EMT_Ph1_General2TerminalSSN_RLCVs_generalizedSSN info] Simulation finished.

# %% [markdown]
# ### Load Results

# %%
from villas.dataprocessing.readtools import *
from villas.dataprocessing.timeseries import *
from villas.dataprocessing.timeseries import TimeSeries as ts
import matplotlib.pyplot as plt
import re
import numpy as np
import math

work_dir = os.getcwd() + "/logs/"
path_logfile_C1R1Vs_RC = work_dir + name + "_C1R1Vs_RC/" + name + "_C1R1Vs_RC" + ".csv"
ts_EMT_Ph1_C1R1Vs_RC = read_timeseries_dpsim(path_logfile_C1R1Vs_RC)
path_logfile_C1R1Vs_generalizedSSN = work_dir + name + "_C1R1Vs_generalizedSSN/" + name + "_C1R1Vs_generalizedSSN" + ".csv"
ts_EMT_Ph1_C1R1Vs_generalizedSSN = read_timeseries_dpsim(path_logfile_C1R1Vs_generalizedSSN)

path_logfile_L1R1Vs_RC = work_dir + name + "_L1R1Vs_RC/" + name + "_L1R1Vs_RC" + ".csv"
ts_EMT_Ph1_L1R1Vs_RC = read_timeseries_dpsim(path_logfile_L1R1Vs_RC)
path_logfile_L1R1Vs_generalizedSSN = work_dir + name + "_L1R1Vs_generalizedSSN/" + name + "_L1R1Vs_generalizedSSN" + ".csv"
ts_EMT_Ph1_L1R1Vs_generalizedSSN = read_timeseries_dpsim(path_logfile_L1R1Vs_generalizedSSN)

path_logfile_RLCVs_RC = work_dir + name + "_RLCVs_RC/" + name + "_RLCVs_RC" + ".csv"
ts_EMT_Ph1_RLCVs_RC = read_timeseries_dpsim(path_logfile_RLCVs_RC)
path_logfile_RLCVs_explicitSSN = work_dir + name + "_RLCVs_explicitSSN/" + name + "_RLCVs_explicitSSN" + ".csv"
ts_EMT_Ph1_RLCVs_explicitSSN = read_timeseries_dpsim(path_logfile_RLCVs_explicitSSN)
path_logfile_RLCVs_generalizedSSN = work_dir + name + "_RLCVs_generalizedSSN/" + name + "_RLCVs_generalizedSSN" + ".csv"
ts_EMT_Ph1_RLCVs_generalizedSSN = read_timeseries_dpsim(path_logfile_RLCVs_generalizedSSN)
# Out:
# column number: 2
# results length: 1001
# real column names: ['i_c_rc', 'v_c_rc']
# complex column names: []
# column number: 2
# results length: 1001
# real column names: ['i_c_genSSN', 'v_c_genSSN']
# complex column names: []
# column number: 2
# results length: 1001
# real column names: ['i_l_rc', 'v_l_rc']
# complex column names: []
# column number: 2
# results length: 1001
# real column names: ['i_l_genSSN', 'v_l_genSSN']
# complex column names: []
# column number: 2
# results length: 1001
# real column names: ['i_l_rlc_rc', 'v_l_rlc_rc']
# complex column names: []
# column number: 2
# results length: 1001
# real column names: ['i_rlc_explSSN', 'v_rlc_explSSN']
# complex column names: []
# column number: 2
# results length: 1001
# real column names: ['i_rlc_genSSN', 'v_rlc_genSSN']
# complex column names: []

# %% [markdown]
# ## Plot C1R1Vs circuit results

# %%
plt.close("all")
fig1 = plt.figure()

plt.plot(
    ts_EMT_Ph1_C1R1Vs_RC["v_c_rc"].time,
    ts_EMT_Ph1_C1R1Vs_RC["v_c_rc"].values,
    "b-",
    label="v_c_rc",
)
plt.plot(
    ts_EMT_Ph1_C1R1Vs_generalizedSSN["v_c_genSSN"].time,
    ts_EMT_Ph1_C1R1Vs_generalizedSSN["v_c_genSSN"].values,
    "bx",
    markevery=5,
    label="v_c_genSSN",
)

plt.legend(loc=4)

plt.title("RC vs generalized SSN simulation: Capacitor voltage")
plt.xlabel("t [s]")
plt.ylabel("Capacitor Voltage [V]")


fig2 = plt.figure()

plt.plot(
    ts_EMT_Ph1_C1R1Vs_RC["i_c_rc"].time,
    ts_EMT_Ph1_C1R1Vs_RC["i_c_rc"].values,
    "r-",
    label="i_c_rc",
)
plt.plot(
    ts_EMT_Ph1_C1R1Vs_generalizedSSN["i_c_genSSN"].time,
    ts_EMT_Ph1_C1R1Vs_generalizedSSN["i_c_genSSN"].values,
    "rx",
    markevery=5,
    label="i_c_genSSN",
)

plt.legend(loc=4)

plt.title("RC vs generalized SSN simulation: Capacitor current")
plt.xlabel("t [s]")
plt.ylabel("Capacitor Current [A]")
# Out:
# Text(0, 0.5, 'Capacitor Current [A]')
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %% [markdown]
# ## Plot L1R1Vs circuit results

# %%
fig3 = plt.figure()

plt.plot(
    ts_EMT_Ph1_L1R1Vs_RC["v_l_rc"].time,
    ts_EMT_Ph1_L1R1Vs_RC["v_l_rc"].values,
    "b-",
    label="v_l_rc",
)
plt.plot(
    ts_EMT_Ph1_L1R1Vs_generalizedSSN["v_l_genSSN"].time,
    ts_EMT_Ph1_L1R1Vs_generalizedSSN["v_l_genSSN"].values,
    "bx",
    markevery=5,
    label="v_l_genSSN",
)

plt.legend(loc=4)

plt.title("RC vs generalized SSN simulation: Inductor voltage")
plt.xlabel("t [s]")
plt.ylabel("Inductor Voltage [V]")


fig4 = plt.figure()

plt.plot(
    ts_EMT_Ph1_L1R1Vs_RC["i_l_rc"].time,
    ts_EMT_Ph1_L1R1Vs_RC["i_l_rc"].values,
    "r-",
    label="i_l_rc",
)
plt.plot(
    ts_EMT_Ph1_L1R1Vs_generalizedSSN["i_l_genSSN"].time,
    ts_EMT_Ph1_L1R1Vs_generalizedSSN["i_l_genSSN"].values,
    "rx",
    markevery=5,
    label="i_l_genSSN",
)

plt.legend(loc=4)

plt.title("RC vs generalized SSN simulation: Inductor current")
plt.xlabel("t [s]")
plt.ylabel("Inductor Current [A]")
# Out:
# Text(0, 0.5, 'Inductor Current [A]')
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %% [markdown]
# ## Plot RLCVs circuit results

# %%
fig5 = plt.figure()

plt.plot(
    ts_EMT_Ph1_RLCVs_RC["i_l_rlc_rc"].time,
    ts_EMT_Ph1_RLCVs_RC["i_l_rlc_rc"].values,
    "r-",
    label="i_rlc_rc",
)
plt.plot(
    ts_EMT_Ph1_RLCVs_explicitSSN["i_rlc_explSSN"].time,
    ts_EMT_Ph1_RLCVs_explicitSSN["i_rlc_explSSN"].values,
    "rx",
    markevery=8,
    label="i_rlc_explSSN",
)
plt.plot(
    ts_EMT_Ph1_RLCVs_generalizedSSN["i_rlc_genSSN"].time,
    ts_EMT_Ph1_RLCVs_generalizedSSN["i_rlc_genSSN"].values,
    "bx",
    markevery=(4,8),
    label="i_rlc_genSSN",
)

plt.legend(loc=4)

plt.title("RC vs explicit SSN vs generalized SSN: RLC current")
plt.xlabel("t [s]")
plt.ylabel("RLC branch current [A]")
# Out:
# Text(0, 0.5, 'RLC branch current [A]')
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %% [markdown]
# ## Assert

# %%
epsilon = 1e-100

#Capacitor circuit
assert (
    np.max(
        ts_EMT_Ph1_C1R1Vs_RC["v_c_rc"].values
        - ts_EMT_Ph1_C1R1Vs_generalizedSSN["v_c_genSSN"].values
    )
    < epsilon
)
assert (
    np.max(
        ts_EMT_Ph1_C1R1Vs_RC["i_c_rc"].values
        - ts_EMT_Ph1_C1R1Vs_generalizedSSN["i_c_genSSN"].values
    )
    < epsilon
)

#Inductor circuit
assert (
    np.max(
        ts_EMT_Ph1_L1R1Vs_RC["v_l_rc"].values
        - ts_EMT_Ph1_L1R1Vs_generalizedSSN["v_l_genSSN"].values
    )
    < epsilon
)
assert (
    np.max(
        ts_EMT_Ph1_L1R1Vs_RC["i_l_rc"].values
        - ts_EMT_Ph1_L1R1Vs_generalizedSSN["i_l_genSSN"].values
    )
    < epsilon
)
    
#RLC circuit
assert (
    np.max(
        ts_EMT_Ph1_RLCVs_RC["i_l_rlc_rc"].values
        - ts_EMT_Ph1_RLCVs_explicitSSN["i_rlc_explSSN"].values
    )
    < epsilon
)
assert (
    np.max(
        ts_EMT_Ph1_RLCVs_RC["i_l_rlc_rc"].values
        - ts_EMT_Ph1_RLCVs_generalizedSSN["i_rlc_genSSN"].values
    )
    < epsilon
)
assert (
    np.max(
        ts_EMT_Ph1_RLCVs_explicitSSN["i_rlc_explSSN"].values
        - ts_EMT_Ph1_RLCVs_generalizedSSN["i_rlc_genSSN"].values
    )
    < epsilon
)
